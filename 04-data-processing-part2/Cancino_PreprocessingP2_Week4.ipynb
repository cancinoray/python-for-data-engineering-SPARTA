# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Part 1

# %%
newdata = pd.read_csv('Cancino_sales.csv')

# %%
newdata
# Out:
#      Transaction_date   Product   Price Payment_Type               Name  \
# 0     01/02/2009 6:17  Product1  1200.0   Mastercard           carolina
# 1     01/02/2009 4:53  Product1  1200.0         Visa             Betina
# 2    01/02/2009 13:08  Product1  1200.0   Mastercard  Federica e Andrea
# 3    01/03/2009 14:44  Product1  1200.0         Visa              Gouya
# 4    01/04/2009 12:56  Product2  3600.0         Visa            Gerd W
# ..                ...       ...     ...          ...                ...
# 995   1/22/2009 14:25  Product1  1200.0         Visa         Hans-Joerg
# 996    1/28/2009 5:36  Product2  3600.0         Visa         Christiane
# 997   01/01/2009 4:24  Product3  7500.0         Amex             Pamela
# 998  01/08/2009 11:55  Product1  1200.0       Diners              julie
# 999  01/12/2009 21:30  Product1  1200.0         Visa             Julia
#
#                              City             State         Country  \
# ...

# %% [markdown]
# ### Removing the Outlier

# %%
newdata.describe(include = 'all' )
# Out:
#        Transaction_date   Product         Price Payment_Type   Name    City  \
# count               997       997    999.000000          997   1000     996
# unique              979         4           NaN            4    761     752
# top     1/14/2009 12:07  Product1           NaN         Visa  Sarah  London
# freq                  2       846           NaN          520     11      19
# mean                NaN       NaN   1650.970971          NaN    NaN     NaN
# std                 NaN       NaN   1210.577115          NaN    NaN     NaN
# min                 NaN       NaN     20.000000          NaN    NaN     NaN
# 25%                 NaN       NaN   1200.000000          NaN    NaN     NaN
# 50%                 NaN       NaN   1200.000000          NaN    NaN     NaN
# 75%                 NaN       NaN   1200.000000          NaN    NaN     NaN
# max                 NaN       NaN  13000.000000          NaN    NaN     NaN
#
# ...

# %%
m = np. mean(newdata.Price)
s = np.std(newdata.Price)

print (m)
print(s)

ll = max(0 , m -3*s)
print (ll)

ul = m + 3*s
print (ul)
# Out:
# 1650.970970970971
# 1209.9710691360758
# 0
# 5280.884178379198

# %%
newdata_cleaned1 = newdata[newdata.Price >= ll]
newdata_cleaned2 = newdata_cleaned1[newdata_cleaned1.Price <= ul]

# %%
newdata_cleaned2.describe(include = 'all' )
# Out:
#        Transaction_date   Product        Price Payment_Type   Name    City  \
# count               978       978   981.000000          979    981     977
# unique              960         2          NaN            4    750     741
# top     01/05/2009 5:33  Product1          NaN         Visa  Sarah  London
# freq                  2       842          NaN          511     11      19
# mean                NaN       NaN  1534.169215          NaN    NaN     NaN
# std                 NaN       NaN   834.950840          NaN    NaN     NaN
# min                 NaN       NaN    20.000000          NaN    NaN     NaN
# 25%                 NaN       NaN  1200.000000          NaN    NaN     NaN
# 50%                 NaN       NaN  1200.000000          NaN    NaN     NaN
# 75%                 NaN       NaN  1200.000000          NaN    NaN     NaN
# max                 NaN       NaN  3600.000000          NaN    NaN     NaN
#
# ...

# %% [markdown]
# ### Standardizing the Price column

# %%
newdata_cleaned2.insert(4 , 'Standardized' , 0)

# %%
newdata_cleaned2
# Out:
#      Transaction_date   Product   Price Payment_Type  Standardized  \
# 0     01/02/2009 6:17  Product1  1200.0   Mastercard             0
# 1     01/02/2009 4:53  Product1  1200.0         Visa             0
# 2    01/02/2009 13:08  Product1  1200.0   Mastercard             0
# 3    01/03/2009 14:44  Product1  1200.0         Visa             0
# 4    01/04/2009 12:56  Product2  3600.0         Visa             0
# ..                ...       ...     ...          ...           ...
# 994   1/20/2009 10:42  Product2  3600.0       Diners             0
# 995   1/22/2009 14:25  Product1  1200.0         Visa             0
# 996    1/28/2009 5:36  Product2  3600.0         Visa             0
# 998  01/08/2009 11:55  Product1  1200.0       Diners             0
# 999  01/12/2009 21:30  Product1  1200.0         Visa             0
#
#                   Name                          City             State  \
# 0             carolina                      Basildon           England
# ...

# %%
###Standardization Formula: Xnew = (Xold - mean)/ standard deviation

newdata_cleaned2.Standardized = (newdata_cleaned2.Price - np.mean(newdata_cleaned2.Price))/(np.std(newdata_cleaned2.Price))
# Out:
# C:\Users\User\Desktop\Ray\env\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
np.mean(newdata_cleaned2.Price)
# Out:
# 1534.1692150866463

# %%
np.std(newdata_cleaned2.Price)
# Out:
# 834.5251709006512

# %%
newdata_cleaned2
# Out:
#      Transaction_date   Product   Price Payment_Type  Standardized  \
# 0     01/02/2009 6:17  Product1  1200.0   Mastercard     -0.400430
# 1     01/02/2009 4:53  Product1  1200.0         Visa     -0.400430
# 2    01/02/2009 13:08  Product1  1200.0   Mastercard     -0.400430
# 3    01/03/2009 14:44  Product1  1200.0         Visa     -0.400430
# 4    01/04/2009 12:56  Product2  3600.0         Visa      2.475457
# ..                ...       ...     ...          ...           ...
# 994   1/20/2009 10:42  Product2  3600.0       Diners      2.475457
# 995   1/22/2009 14:25  Product1  1200.0         Visa     -0.400430
# 996    1/28/2009 5:36  Product2  3600.0         Visa      2.475457
# 998  01/08/2009 11:55  Product1  1200.0       Diners     -0.400430
# 999  01/12/2009 21:30  Product1  1200.0         Visa     -0.400430
#
#                   Name                          City             State  \
# 0             carolina                      Basildon           England
# ...

# %% [markdown]
# ### Part 2

# %%
data = pd.read_csv("Cancino_Handling_Missing_Values.csv")

# %%
data
# Out:
#     ID     Sex  Age   Income Employed  Children Buy_Car
# 0    1    Male   25  25146.0   Single       0.0      No
# 1    2    Male   30  26939.0  Married       2.0     Yes
# 2    3    Male   27  26693.0  Married       0.0      No
# 3    4    Male   28  26666.0  Married       3.0     Yes
# 4    5    Male   29  25899.0  Married       0.0      No
# 5    6    Male   28  26462.0  Married       1.0      No
# 6    7  Female   28      NaN  Married       3.0     Yes
# 7    8     NaN   30  26037.0  Married       2.0     Yes
# 8    9  Female   28  26167.0  Married       1.0     Yes
# 9   10     NaN   28      NaN   Single       NaN      No
# 10  11  Female   28  26905.0   Single       0.0      No
# 11  12    Male   30  26195.0   Single       NaN     Yes
# 12  13  Female   30  26514.0  Married       4.0     Yes
# 13  14  Female   28  26969.0  Married       4.0     Yes
# 14  15     NaN   28  26234.0  Married       0.0      No
# 15  16    Male   27  26229.0  Married       0.0      No
# ...

# %%
data.isnull().sum()
# Out:
# ID          0
# Sex         4
# Age         0
# Income      3
# Employed    0
# Children    2
# Buy_Car     0
# dtype: int64

# %%
## Columns with missing data
## Define null columns
null_columns = data.columns[data.isnull().any()]

## Print columns containing null values
data[data.isnull().any(axis = 1)][null_columns]
# Out:
#        Sex   Income  Children
# 6   Female      NaN       3.0
# 7      NaN  26037.0       2.0
# 9      NaN      NaN       NaN
# 11    Male  26195.0       NaN
# 14     NaN  26234.0       0.0
# 17     NaN      NaN       0.0

# %%
## I choose to delete the rows that containing NaN values more than 2
data = data.dropna(thresh = 6,  axis=0)
data
# Out:
#     ID     Sex  Age   Income Employed  Children Buy_Car
# 0    1    Male   25  25146.0   Single       0.0      No
# 1    2    Male   30  26939.0  Married       2.0     Yes
# 2    3    Male   27  26693.0  Married       0.0      No
# 3    4    Male   28  26666.0  Married       3.0     Yes
# 4    5    Male   29  25899.0  Married       0.0      No
# 5    6    Male   28  26462.0  Married       1.0      No
# 6    7  Female   28      NaN  Married       3.0     Yes
# 7    8     NaN   30  26037.0  Married       2.0     Yes
# 8    9  Female   28  26167.0  Married       1.0     Yes
# 10  11  Female   28  26905.0   Single       0.0      No
# 11  12    Male   30  26195.0   Single       NaN     Yes
# 12  13  Female   30  26514.0  Married       4.0     Yes
# 13  14  Female   28  26969.0  Married       4.0     Yes
# 14  15     NaN   28  26234.0  Married       0.0      No
# 15  16    Male   27  26229.0  Married       0.0      No
# 16  17  Female   26  25094.0  Married       0.0      No
# ...

# %%
## Columns with missing data
## Define null columns
null_columns = data.columns[data.isnull().any()]

## Print columns containing null values
data[data.isnull().any(axis = 1)][null_columns]
# Out:
#        Sex   Income  Children
# 6   Female      NaN       3.0
# 7      NaN  26037.0       2.0
# 11    Male  26195.0       NaN
# 14     NaN  26234.0       0.0

# %%
#Data Imputation
#Data Imputation: Mean
#Replacing missing values using mean

mean_value = data['Income'].mean() #getting the mean

print(mean_value)

data['Income'] = data['Income'].fillna(mean_value) #fill mean values

# For me, it's logical to use mean to fill out the NaN values in Income column,as comparing the relationship between the income and the age

data
# Out:
# 26245.70588235294
# C:\Users\User\AppData\Local\Temp/ipykernel_14156/1484207687.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Income'] = data['Income'].fillna(mean_value) #fill mean values
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 0    1    Male   25  25146.000000   Single       0.0      No
# 1    2    Male   30  26939.000000  Married       2.0     Yes
# 2    3    Male   27  26693.000000  Married       0.0      No
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 4    5    Male   29  25899.000000  Married       0.0      No
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# ...

# %%
#Data Imputation
#Data Imputation: Mode
#Replacing missing values using mode

mode_value = data['Sex'].mode() #getting the mode

print(mode_value)

data['Sex'] = data['Sex'].fillna(mode_value[0]) #fill mode values
data

#I use the mode because we are dealing with categorical values.
# Out:
# 0    Male
# dtype: object
# C:\Users\User\AppData\Local\Temp/ipykernel_14156/2441264055.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sex'] = data['Sex'].fillna(mode_value[0]) #fill mode values
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 0    1    Male   25  25146.000000   Single       0.0      No
# 1    2    Male   30  26939.000000  Married       2.0     Yes
# 2    3    Male   27  26693.000000  Married       0.0      No
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 4    5    Male   29  25899.000000  Married       0.0      No
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# ...

# %%
#Data Imputation
#Data Imputation: Median
#Replacing missing values using mode

median_value = data['Children'].median() #getting the median

print(median_value)

data['Children'] = data['Children'].fillna(median_value) #fill median values
data

#in the data it is logical to use the median to fill out the NaN values
# Out:
# 1.0
# C:\Users\User\AppData\Local\Temp/ipykernel_14156/1348119797.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Children'] = data['Children'].fillna(median_value) #fill median values
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 0    1    Male   25  25146.000000   Single       0.0      No
# 1    2    Male   30  26939.000000  Married       2.0     Yes
# 2    3    Male   27  26693.000000  Married       0.0      No
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 4    5    Male   29  25899.000000  Married       0.0      No
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# ...

# %% [markdown]
# ### Part 3

# %%
empty = pd.read_csv("Cancino_empty.csv")

# %%
empty
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#I will try to identify and remove the outlier

empty.describe(include = 'all' )
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
m2 = np. mean(empty.cp)
s2 = np.std(empty.cp)

print (m2)
print(s2)

ll2 = max(0 , m2 -3*s2)
print (ll2)

ul2 = m2 + 3*s2
print (ul2)
# Out:
# 0.966996699669967
# 1.0303480250839467
# 0
# 4.058040774921808

# %%
empty_cleaned1 = empty[empty.cp >= ll]
empty_cleaned2 = empty[empty.cp <= ul]

# %%
empty_cleaned2.describe(include = 'all' )

#as we can see all the data is in the range.
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#Now I'll standardized the cp
empty_cleaned2.insert(3 , 'Standardized_cp' , 0)

###Standardization Formula: Xnew = (Xold - mean)/ standard deviation

empty_cleaned2.Standardized_cp = (empty_cleaned2.cp - np.mean(empty_cleaned2.cp))/(np.std(empty_cleaned2.cp))

# %%
empty_cleaned2
# Out:
#      age  sex  cp  Standardized_cp  trestbps  chol  fbs  restecg  thalach  \
# 0     63    1   3         1.973123       145   233    1        0      150
# 1     37    1   2         1.002577       130   250    0        1      187
# 2     41    0   1         0.032031       130   204    0        0      172
# 3     56    1   1         0.032031       120   236    0        1      178
# 4     57    0   0        -0.938515       120   354    0        1      163
# ..   ...  ...  ..              ...       ...   ...  ...      ...      ...
# 298   57    0   0        -0.938515       140   241    0        1      123
# 299   45    1   3         1.973123       110   264    0        1      132
# 300   68    1   0        -0.938515       144   193    1        1      141
# 301   57    1   0        -0.938515       130   131    0        1      115
# 302   57    0   1         0.032031       130   236    0        0      174
#
#      exang  oldpeak  slope  ca  thal  target
# ...

# %%
#Now I'll standardized the trestbps
empty_cleaned2.insert(5 , 'Standardized_trestbps' , 0)

###Standardization Formula: Xnew = (Xold - mean)/ standard deviation

empty_cleaned2.Standardized_trestbps = (empty_cleaned2.trestbps - np.mean(empty_cleaned2.trestbps))/(np.std(empty_cleaned2.trestbps))

# %%
empty_cleaned2
# Out:
#      age  sex  cp  Standardized_cp  trestbps  Standardized_trestbps  chol  \
# 0     63    1   3         1.973123       145               0.763956   233
# 1     37    1   2         1.002577       130              -0.092738   250
# 2     41    0   1         0.032031       130              -0.092738   204
# 3     56    1   1         0.032031       120              -0.663867   236
# 4     57    0   0        -0.938515       120              -0.663867   354
# ..   ...  ...  ..              ...       ...                    ...   ...
# 298   57    0   0        -0.938515       140               0.478391   241
# 299   45    1   3         1.973123       110              -1.234996   264
# 300   68    1   0        -0.938515       144               0.706843   193
# 301   57    1   0        -0.938515       130              -0.092738   131
# 302   57    0   1         0.032031       130              -0.092738   236
#
#      fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# ...

# %%
#Now I'll standardized the chol
empty_cleaned2.insert(7 , 'Standardized_chol' , 0)

###Standardization Formula: Xnew = (Xold - mean)/ standard deviation

empty_cleaned2.Standardized_chol = (empty_cleaned2.chol - np.mean(empty_cleaned2.chol))/(np.std(empty_cleaned2.chol))

# %%
empty_cleaned2
# Out:
#      age  sex  cp  Standardized_cp  trestbps  Standardized_trestbps  chol  \
# 0     63    1   3         1.973123       145               0.763956   233
# 1     37    1   2         1.002577       130              -0.092738   250
# 2     41    0   1         0.032031       130              -0.092738   204
# 3     56    1   1         0.032031       120              -0.663867   236
# 4     57    0   0        -0.938515       120              -0.663867   354
# ..   ...  ...  ..              ...       ...                    ...   ...
# 298   57    0   0        -0.938515       140               0.478391   241
# 299   45    1   3         1.973123       110              -1.234996   264
# 300   68    1   0        -0.938515       144               0.706843   193
# 301   57    1   0        -0.938515       130              -0.092738   131
# 302   57    0   1         0.032031       130              -0.092738   236
#
#      Standardized_chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# ...

# %%
###Now I can see exactly how near or far the cp, trestbps and chol in the mean.
